# %%
import pandas as pd

# %%
nountrain = pd.read_json('../../outputs/rollouts/nounsynthrmppo.jsonl', orient='records', lines=True)

# %%
def make_dpodata():

# %%
nountrain
# Out:
#                                                 inputs  \
# 0    [How does Walmart address sustainability and s...
# 1    [Generate response to the question/instruction...
# 2    [What are some of the key features to look for...
# 3    [Given the text: The 15th annual arthur ashe e...
# 4    [Are there any suggested modifications to the ...
# ..                                                 ...
# 695  [What traditional dishes can be found in Taran...
# 696  [Is there any indication of what kind of struc...
# 697  [Explain the importance of researching and sel...
# 698  [Can a lack of positive reinforcement from par...
# 699  [Write an instructional article on how to make...
#
#                                                outputs  \
# 0    [\nWhat will Wal-Mart accomplish to help raise...
# 1    [\n Credits Rudy Justice for his contribution ...
# 2    [\nThe description just contained code that co...
# 3    [ You have been awarded an arthur ashe essay c...
# ...
